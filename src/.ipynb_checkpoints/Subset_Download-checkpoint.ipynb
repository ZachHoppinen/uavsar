# %%
import geehydro
from rasterio.windows import from_bounds
from rasterio.enums import Resampling
import os
from os.path import join, basename
import numpy as np
import pandas as pd
#import rioxarray
import matplotlib.pyplot as plt
import rasterio as rio
#from osgeo import gdal
from rasterio.windows import Window , from_bounds, crop
import folium
import pyproj

# %%
import ee
ee.Authenticate()
ee.Initialize()
# Out:
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://accounts.google.com/o/oauth2/auth?client_id=517222506229-vsmmajv00ul0bs7p89v5m89qs8eb9359.apps.googleusercontent.com&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fearthengine+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdevstorage.full_control&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&response_type=code&code_challenge=ilkIHEAuZkiKP5zcF4DDod-gHQ-16J4t8pyF10-dEFc&code_challenge_method=S256>https://accounts.google.com/o/oauth2/auth?client_id=517222506229-vsmmajv00ul0bs7p89v5m89qs8eb9359.apps.googleusercontent.com&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fearthengine+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdevstorage.full_control&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&response_type=code&code_challenge=ilkIHEAuZkiKP5zcF4DDod-gHQ-16J4t8pyF10-dEFc&code_challenge_method=S256</a></p>
#         <p>The authorization workflow will generate a code, which you
#         should paste in the box below</p>
# Enter verification code: 4/1AX4XfWjrqYd8eYApv-jVEZNe_Xuth-TZbg0g1rYzgCZI5LDLvFYvySAYOw8
#
# Successfully saved authorization token.

# %%
home_dir = '/home/zacharykeskinen/Documents/uavsar/'
data_dir = join(home_dir,'data')
url_dir = join(data_dir, 'urls')
imgs_dir = join(home_dir, 'imgs')
loc_dir = (join(imgs_dir, os.listdir(imgs_dir)[0]))

class Image:
    def __init__(self, fp, dtype, pol, real_img):
        self.fp = fp
        self.dtype = dtype
        self.pol = pol
        self.comp = real_img
    array = None
    top = None
    bottom = None
    left = None
    right = None
    crs = None
    transform = None
    window = None
    nodata = None

img_list = []
        
for img in os.listdir(loc_dir):
    if 'csv' in img:
        desc = pd.read_csv(join(loc_dir, img))
    if 'tif' in img:
        if len(basename(img).split('.')) == 3:
            fp = join(loc_dir, img)
            real_img = 'real'
            dtype = basename(img).split('.')[-2]
            pol = np.nan
            img_list.append(Image(fp, dtype, pol, real_img))
        else:
            fp = join(loc_dir, img)
            real_img = basename(img).split('.')[-2]
            dtype = basename(img).split('.')[-3]
            pol = basename(img).split('.')[0].split('_')[-2][4:]
            img_list.append(Image(fp, dtype, pol, real_img))

# %%
for col in desc.columns:
    print(col)
    print(desc.loc[0,col])
    print('-----------------')
# Out:
# Unnamed: 0
# value
# -----------------
# uavsar rpi annotation file version number
# 2.3
# -----------------
# site description
# Lowman, CO
# -----------------
# flight plan comments of pass 1
# nan
# -----------------
# flight plan comments of pass 2
# nan
# -----------------
# processing comments
# nan
# -----------------
# url
# http://uavsar.jpl.nasa.gov/cgi-bin/product.pl?jobName
# -----------------
# slant range interferogram
# lowman_05208_21019-019_21021-007_0006d_s01_L090VV_01.int
# -----------------
# slant range unwrapped phase
# lowman_05208_21019-019_21021-007_0006d_s01_L090VV_01.unw
# -----------------
# slant range correlation
# lowman_05208_21019-019_21021-007_0006d_s01_L090VV_01.cor
# -----------------
# slant range amplitude of pass 1
# lowman_05208_21019-019_21021-007_0006d_s01_L090VV_01.amp1
# -----------------
# slant range amplitude of pass 2
# lowman_05208_21019-019_21021-007_0006d_s01_L090VV_01.amp2
# -----------------
# ground range interferogram
# lowman_05208_21019-019_21021-007_0006d_s01_L090VV_01.int.grd
# -----------------
# ground range unwrapped phase
# lowman_05208_21019-019_21021-007_0006d_s01_L090VV_01.unw.grd
# -----------------
# ground range correlation
# lowman_05208_21019-019_21021-007_0006d_s01_L090VV_01.cor.grd
# -----------------
# ground range amplitude of pass 1
# lowman_05208_21019-019_21021-007_0006d_s01_L090VV_01.amp1.grd
# -----------------
# ground range amplitude of pass 2
# lowman_05208_21019-019_21021-007_0006d_s01_L090VV_01.amp2.grd
# -----------------
# dem used in ground projection
# lowman_05208_21019-019_21021-007_0006d_s01_L090VV_01.hgt.grd
# -----------------
# kmz of ground range interferogram
# lowman_05208_21019-019_21021-007_0006d_s01_L090VV_01.int.kmz
# -----------------
# kmz of ground range unwrapped phase
# lowman_05208_21019-019_21021-007_0006d_s01_L090VV_01.unw.kmz
# -----------------
# kmz of ground range correlation
# lowman_05208_21019-019_21021-007_0006d_s01_L090VV_01.cor.kmz
# -----------------
# kmz of ground range amplitude of pass 1
# lowman_05208_21019-019_21021-007_0006d_s01_L090VV_01.amp1.kmz
# -----------------
# kmz of ground range amplitude of pass 2
# lowman_05208_21019-019_21021-007_0006d_s01_L090VV_01.amp2.kmz
# -----------------
# kmz of dem used in ground projection
# lowman_05208_21019-019_21021-007_0006d_s01_L090VV_01.hgt.kmz
# -----------------
# single look complex data of pass 1
# lowman_05208_21019-019_21021-007_0006d_s01_L090VV_01.T1.slc
# -----------------
# single look complex data of pass 2
# lowman_05208_21019-019_21021-007_0006d_s01_L090VV_01.T2.slc
# -----------------
# slant range data azimuth lines
# 18420
# -----------------
# slant range data range samples
# 3300
# -----------------
# slant range data starting azimuth
# -66609.3
# -----------------
# slant range data at near range
# 12249.65231366
# -----------------
# slant range data azimuth spacing
# 7.2
# -----------------
# slant range data range spacing
# 4.99654098
# -----------------
# number of looks in range
# 3
# -----------------
# number of looks in azimuth
# 12
# -----------------
# ground range data latitude lines
# 17256
# -----------------
# ground range data longitude samples
# 26602
# -----------------
# ground range data starting latitude
# 44.512171800000004
# -----------------
# ground range data starting longitude
# -116.32236060000001
# -----------------
# ground range data latitude spacing
# -5.556e-05
# -----------------
# ground range data longitude spacing
# 5.556e-05
# -----------------
# approximate upper left latitude
# 44.48141846
# -----------------
# approximate upper left longitude
# -115.02461844
# -----------------
# approximate upper right latitude
# 44.34243925
# -----------------
# approximate upper right longitude
# -114.86780143
# -----------------
# approximate lower left latitude
# 43.73704274
# -----------------
# approximate lower left longitude
# -116.3179904
# -----------------
# approximate lower right latitude
# 43.58254601
# -----------------
# approximate lower right longitude
# -116.13736813
# -----------------
# single look complex data azimuth lines
# 221040
# -----------------
# single look complex data range samples
# 9900
# -----------------
# single look complex data starting azimuth
# -66612.6
# -----------------
# single look complex data at near range
# 12247.9868
# -----------------
# single look complex data azimuth spacing
# 0.6
# -----------------
# single look complex data range spacing
# 1.66551366
# -----------------
# interferogram bytes per pixel
# 8
# -----------------
# unwrapped phase bytes per pixel
# 4
# -----------------
# correlation bytes per pixel
# 4
# -----------------
# amplitude bytes per pixel
# 4
# -----------------
# dem bytes per pixel
# 4
# -----------------
# slc bytes per pixel
# 8
# -----------------
# interferogram pixel format
# Complex
# -----------------
# unwrapped phase pixel format
# Real
# -----------------
# correlation pixel format
# Real
# -----------------
# amplitude pixel format
# Real
# -----------------
# dem pixel format
# Real
# -----------------
# slc pixel format
# Complex
# -----------------
# interferogram units
# Linear Power and Phase in Radians
# -----------------
# unwrapped phase units
# Radians
# -----------------
# correlation units
# Scalar Between 0 and 1
# -----------------
# amplitude units
# Linear Amplitude
# -----------------
# dem units
# Meters
# -----------------
# slc units
# Linear Amplitude and Phase in Radians
# -----------------
# acquisition mode
# PolSAR
# -----------------
# radar look direction
# Left
# -----------------
# flight path
# Geodesic
# -----------------
# number of repeat passes
# 2
# -----------------
# steering angle
# 90
# -----------------
# average look angle in near range
# 28.96
# -----------------
# average look angle in far range
# 68.1
# -----------------
# bandwidth
# 80.0
# -----------------
# center wavelength
# 23.8403545
# -----------------
# pulse length
# 40.0
# -----------------
# ping-pong or single antenna transmit
# Ping-Pong
# -----------------
# nominal azimuth reference length
# 8192
# -----------------
# average pulse repetition interval
# 2.4493979
# -----------------
# global average yaw
# -2.57566203
# -----------------
# global average pitch
# 0.64568995
# -----------------
# global average roll
# 0.0
# -----------------
# global average esa
# 1.6029377
# -----------------
# global average squint angle
# -0.2369885
# -----------------
# global average altitude
# 12495.2121
# -----------------
# global average terrain height
# 1778.86941
# -----------------
# standard deviation of terrain height
# 399.078089
# -----------------
# barometric pressure during pass 1
# nan
# -----------------
# barometric pressure during pass 2
# nan
# -----------------
# flight id for pass 1
# 21019
# -----------------
# flight id for pass 2
# 21021
# -----------------
# start time of acquisition for pass 1
# 2021-03-16 12:09:32-06:00
# -----------------
# stop time of acquisition for pass 1
# 2021-03-16 12:19:25-06:00
# -----------------
# start time of acquisition for pass 2
# 2021-03-22 10:58:37-06:00
# -----------------
# stop time of acquisition for pass 2
# 2021-03-22 11:07:49-06:00
# -----------------
# hardware version number for pass 1
# nan
# -----------------
# hardware version number for pass 2
# nan
# -----------------
# processing mode
# RPI
# -----------------
# polarization
# VV
# -----------------
# peg latitude
# 43.926522137
# -----------------
# peg longitude
# -115.46468854
# -----------------
# peg heading
# 51.809094485
# -----------------
# ellipsoid semi-major axis
# 6378137.0
# -----------------
# ellipsoid eccentricity squared
# 0.00669437999
# -----------------
# cross track offset from reference track
# 0.0
# -----------------
# polarimetrically calibrated
# Yes
# -----------------
# antenna pattern radiometric correction applied
# Yes
# -----------------
# range dependent radiometric correction applied
# Yes
# -----------------
# mocomp i applied
# Yes
# -----------------
# mocomp ii applied
# Yes
# -----------------
# reskew doppler
# Global Doppler
# -----------------
# reskew doppler near mid far
# 31.44043790          -8.56578855         -18.46439655
# -----------------
# rfi removed
# Yes (Quick RFI Removal)
# -----------------
# cross talk removed
# No
# -----------------
# correlation threshold
# nan
# -----------------
# sinc interpolator fractional bandwidth
# 0.9
# -----------------
# residual baseline estimation method
# nan
# -----------------
# number of baseline iterations
# 0
# -----------------
# length of processed data
# 132.624
# -----------------
# date of processing
# 16-Apr-2021
# -----------------
# processor version number
# e73da1e492cc42a649e9ef694feea0d258361562
# -----------------
# post processor version number
# e73da1e492cc42a649e9ef694feea0d258361562
# -----------------
# ground projection method
# Nearest Neighbor
# -----------------
# dem used in processing
# SRTM1 v3
# -----------------
# dem source
# http://uavsar.jpl.nasa.gov/doc/dem.htm
# -----------------
# dem datum
# WGS-84
# -----------------
# dem interpolation method
# Bilinear
# -----------------
# dem original pixel spacing
# 1
# -----------------
# dem citation count
# 0
# -----------------
# slope calibration in ground data
# No
# -----------------
# phase unwrapping method
# ICU
# -----------------
# phase unwrapping filtering method
# Low Pass
# -----------------
# phase unwrapping filter window size
# 3 x 3
# -----------------
# set_name
# nan
# -----------------
# set_plat
# 43.926522137
# -----------------
# set_plon
# -115.46468854
# -----------------
# set_phdg
# 51.809094485
# -----------------
# slt.set_rows
# 18420
# -----------------
# slt.set_cols
# 3300
# -----------------
# slt_mag.set_rows
# 18420
# -----------------
# slt_mag.set_cols
# 3300
# -----------------
# slt_phs.set_rows
# 18420
# -----------------
# slt_phs.set_cols
# 3300
# -----------------
# grd.set_rows
# 17256
# -----------------
# grd.set_cols
# 26602
# -----------------
# grd_mag.set_rows
# 17256
# -----------------
# grd_mag.set_cols
# 26602
# -----------------
# grd_phs.set_rows
# 17256
# -----------------
# grd_phs.set_cols
# 26602
# -----------------
# slc_mag.set_rows
# 221040
# -----------------
# slc_mag.set_cols
# 9900
# -----------------
# slc_phs.set_rows
# 221040
# -----------------
# slc_phs.set_cols
# 9900
# -----------------
# slt.row_addr
# -66609.3
# -----------------
# slt.col_addr
# 12249.65231366
# -----------------
# slt_mag.row_addr
# -66609.3
# -----------------
# slt_mag.col_addr
# 12249.65231366
# -----------------
# slt_phs.row_addr
# -66609.3
# -----------------
# slt_phs.col_addr
# 12249.65231366
# -----------------
# grd.row_addr
# 44.512171800000004
# -----------------
# grd.col_addr
# -116.32236060000001
# -----------------
# grd_mag.row_addr
# 44.512171800000004
# -----------------
# grd_mag.col_addr
# -116.32236060000001
# -----------------
# grd_phs.row_addr
# 44.512171800000004
# -----------------
# grd_phs.col_addr
# -116.32236060000001
# -----------------
# slc_mag.row_addr
# -66612.6
# -----------------
# slc_mag.col_addr
# 12247.9868
# -----------------
# slc_phs.row_addr
# -66612.6
# -----------------
# slc_phs.col_addr
# 12247.9868
# -----------------
# slt.row_mult
# 7.2
# -----------------
# slt.col_mult
# 4.99654098
# -----------------
# slt_mag.row_mult
# 7.2
# -----------------
# slt_mag.col_mult
# 4.99654098
# -----------------
# slt_phs.row_mult
# 7.2
# -----------------
# slt_phs.col_mult
# 4.99654098
# -----------------
# grd.row_mult
# -5.556e-05
# -----------------
# grd.col_mult
# 5.556e-05
# -----------------
# grd_mag.row_mult
# -5.556e-05
# -----------------
# grd_mag.col_mult
# 5.556e-05
# -----------------
# grd_phs.row_mult
# -5.556e-05
# -----------------
# grd_phs.col_mult
# 5.556e-05
# -----------------
# slc_mag.row_mult
# 0.6
# -----------------
# slc_mag.col_mult
# 1.66551366
# -----------------
# slc_phs.row_mult
# 0.6
# -----------------
# slc_phs.col_mult
# 1.66551366
# -----------------
# slt.val_size
# 4
# -----------------
# slt_mag.val_size
# 8
# -----------------
# slt_phs.val_size
# 8
# -----------------
# grd.val_size
# 4
# -----------------
# grd_mag.val_size
# 8
# -----------------
# grd_phs.val_size
# 8
# -----------------
# slc_mag.val_size
# 8
# -----------------
# slc_phs.val_size
# 8
# -----------------
# val_endi
# LITTLE ENDIAN
# -----------------
# slt.val_frmt
# REAL*4
# -----------------
# slt_mag.val_frmt
# COMPLEX_MAGNITUDE
# -----------------
# slt_phs.val_frmt
# COMPLEX_PHASE
# -----------------
# grd.val_frmt
# REAL*4
# -----------------
# grd_mag.val_frmt
# COMPLEX_MAGNITUDE
# -----------------
# grd_phs.val_frmt
# COMPLEX_PHASE
# -----------------
# slc_mag.val_frmt
# COMPLEX_MAGNITUDE
# -----------------
# slc_phs.val_frmt
# COMPLEX_PHASE
# -----------------
# slt.set_proj
# SCX
# -----------------
# slt_mag.set_proj
# SCX
# -----------------
# slt_phs.set_proj
# SCX
# -----------------
# grd.set_proj
# EQA
# -----------------
# grd_mag.set_proj
# EQA
# -----------------
# grd_phs.set_proj
# EQA
# -----------------
# slc_mag.set_proj
# SCX
# -----------------
# slc_phs.set_proj
# SCX
# -----------------
# val_mult
# 1.0
# -----------------
# val_addr
# 0.0
# -----------------
# val_minv
# -1000000.0
# -----------------
# val_maxv
# 10000000.0
# -----------------
# slt_phs.val_mult
# 1.0
# -----------------
# slt_phs.val_minv
# -3.14
# -----------------
# slt_phs.val_maxv
# 3.14
# -----------------
# grd_phs.val_mult
# 1.0
# -----------------
# grd_phs.val_minv
# -3.14
# -----------------
# grd_phs.val_maxv
# 3.14
# -----------------
# slc_phs.val_mult
# 1.0
# -----------------
# slc_phs.val_minv
# -3.14
# -----------------
# slc_phs.val_maxv
# 3.14
# -----------------
# dsp_cmap
# grey
# -----------------
# slt_phs.dsp_cmap
# cmy
# -----------------
# grd_phs.dsp_cmap
# cmy
# -----------------
# slc_phs.dsp_cmap
# cmy
# -----------------
# set_hddr
# 0
# -----------------
# set_tail
# 0
# -----------------

# %%
left = -115.239170
right = -115.188873
top = 44.328928
bottom = 44.305592

# %%
img_list[2].dtype
# Out:
# 'inc'

# %%
Map = folium.Map(location=[bottom,left],
                   tiles='Stamen Terrain', zoom_start = 12)

#unw_list = [x for x in img_list if x.dtype == 'unw']

with rio.open(img_list[2].fp) as src:
    boundary = src.bounds
    
    my_proj = pyproj.Proj(str(src.crs).lower())#your data crs
    left_bottom_lat = my_proj(boundary[0],boundary[1], inverse=True)
    right_top_lat = my_proj(boundary[2],boundary[3], inverse=True)
    img = src.read(1, window=win)
    
# Overlay raster called img using add_child() function (opacity and bounding box set)
Map.add_child(folium.raster_layers.ImageOverlay(img, opacity=1, 
                                 bounds =[[left_bottom_lat[1], left_bottom_lat[0]], [right_top_lat[1], right_top_lat[0]]]))

# To see a google satellite view as a basemap
Map.setOptions('HYBRID')

Map.setControlVisibility(layerControl=True, fullscreenControl=True, latLngPopup=True)

# Display map 
Map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_e1d448a530b546d58ba2c029155388f4%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20.leaflet-image-layer%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20/%2A%20old%20android/safari%2A/%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20image-rendering%3A%20-webkit-optimize-contrast%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20image-rendering%3A%20crisp-edges%3B%20/%2A%20safari%20%2A/%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20image-rendering%3A%20pixelated%3B%20/%2A%20chrome%20%2A/%0A%20%20%20%20%20%20%20%2 ...

# %%
Map = folium.Map(location=[bottom,left],
                   tiles='Stamen Terrain', zoom_start = 12)

site = ee.Geometry.Polygon(
    [[[right, bottom],
      [left, bottom],
      [left, top],
      [right, top]]]);

ic = ee.ImageCollection("NASA/MEASURES/GFCC/TC/v3").filterBounds(site).filterMetadata('year','equals',2015).select('tree_canopy_cover')
tree = ic.mean().reproject(crs = ee.Projection('EPSG:4326'), scale=10)
arr = np.array(tree.sampleRectangle(region = site).get('tree_canopy_cover').getInfo())

with rio.open(img_list[0].fp) as src:
    boundary = src.bounds
    crs = src.crs
    transform_affine = src.transform
    
    my_proj = pyproj.Proj(str(crs).lower())#your data crs

    left_bottom = my_proj(left,bottom, inverse=False)
    right_top = my_proj(right,top, inverse=False)
    win = from_bounds(left_bottom[0], left_bottom[1], right_top[0], right_top[1], src.transform)
    bounds = rio.windows.bounds(win,src.transform)
    img = src.read(1, window=win)
    nodata = src.nodata
print(bottom)
# Overlay raster called img using add_child() function (opacity and bounding box set)
Map.add_child(folium.raster_layers.ImageOverlay(img, opacity=1, 
                                 bounds =[[bottom, left], [top, right]]))

# To see a google satellite view as a basemap
Map.setOptions('HYBRID')

Map.addLayer(tree.clip(site), {'min':0,'max':50}, 'tree coverage')
Map.setControlVisibility(layerControl=True, fullscreenControl=True, latLngPopup=True)

# Display map 
Map
# Out:
# 44.305592
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_ba3d563c54b54e109878251cdb961618%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20.leaflet-image-layer%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20/%2A%20old%20android/safari%2A/%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20image-rendering%3A%20-webkit-optimize-contrast%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20image-rendering%3A%20crisp-edges%3B%20/%2A%20safari%20%2A/%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20image-rendering%3A%20pixelated%3B%20/%2A%20chrome%20%2A/%0A%20%20%20%20%20%20%20%2 ...

# %%
cor_list = [x for x in img_list if x.dtype == 'cor']
with rio.open(cor_list[0].fp) as src:
    
    my_proj = pyproj.Proj(str(src.crs).lower())#your data crs
    left_bottom = my_proj(left,bottom, inverse=False)
    right_top = my_proj(right,top, inverse=False)
    win = from_bounds(left_bottom[0], left_bottom[1], right_top[0], right_top[1], src.transform)
    target_size = src.read(1, window=win).shape

# %%
X, Y = np.mgrid[left:right, bottom:top]
X
# Out:
# array([[-115.23917]])

# %%
from scipy import interpolate
def array_resize(arr, target_shape, kind = 'linear'):

    H, W = arr.shape[:2]
    new_H, new_W = target_shape[:2]
    xrange = lambda x: np.linspace(0, 1, x)

    f = interpolate.interp2d(xrange(W), xrange(H), arr, kind=kind)
    new_arr = f(xrange(new_W), xrange(new_H))
    return new_arr

# %%
left = -115.239170
right = -115.188873
top = 44.328928
bottom = 44.305592

for im in img_list:
    with rio.open(im.fp) as src:
        im.crs = src.crs
        im.transform = src.transform
        im.left = left
        im.right = left
        im.top = top
        im.bottom = bottom
        
        my_proj = pyproj.Proj(str(src.crs).lower())#your data crs
        left_bottom = my_proj(left,bottom, inverse=False)
        right_top = my_proj(right,top, inverse=False)
        
        win = from_bounds(left_bottom[0], left_bottom[1], right_top[0], right_top[1], src.transform)
        im.window = win
        arr = src.read(1, window=win)
        new_arr = array_resize(arr, target_size)
        
        im.array = new_arr
        im.nodata = src.nodata

# %%
import xarray as xr

# %%
sub = xr.Dataset()
for im in img_list:
    sub[f'{im.pol}_{im.dtype}_{im.comp}'] = (('x','y' ), im.array)

# %%
sub
# Out:
# <xarray.Dataset>
# Dimensions:           (x: 533, y: 787)
# Dimensions without coordinates: x, y
# Data variables: (12/29)
#     HH_hgt_real       (x, y) float64 2.125e+03 2.126e+03 ... 2.623e+03 2.624e+03
#     VV_int_imaginary  (x, y) float64 0.01291 0.0104 0.02355 ... 0.01009 0.003904
#     nan_inc_real      (x, y) float64 1.116 1.117 1.117 ... 1.342 1.339 1.337
#     HV_int_real       (x, y) float64 -0.005895 -0.004708 ... -0.0008028 0.001729
#     HH_int_imaginary  (x, y) float64 0.03383 0.02588 0.02119 ... 0.02457 0.01235
#     HH_amp2_real      (x, y) float64 0.164 0.2162 0.2913 ... 0.2012 0.1786
#     ...                ...
#     VH_int_imaginary  (x, y) float64 0.01396 0.005769 ... 0.004846 -0.001372
#     VH_cor_real       (x, y) float64 0.4169 0.2438 0.2243 ... 0.3293 0.2025
#     VH_amp1_real      (x, y) float64 0.277 0.1971 0.1238 ... 0.1983 0.2383
#     VV_int_real       (x, y) float64 0.01199 0.006316 ... -0.009457 -0.005688
#     HV_cor_real       (x, y) float64 0.36 0.3356 0.3162 ... 0.3999 0.3257 0.1749
#     VH_hgt_real       (x, y) float64 2.125e+03 2.126e+03 ... 2.623e+03 2.624e+03
# Attributes: (12/234)
#     uavsar rpi annotation file version number:       2.3 -
#     site description:                                Lowman, CO
#     flight plan comments of pass 1:                  nan
#     flight plan comments of pass 2:                  nan
#     processing comments:                             nan
#     url:                                             http://uavsar.jpl.nasa.g...
#     ...                                              ...
#     dsp_cmap:                                        grey
#     slt_phs.dsp_cmap:                                cmy
#     grd_phs.dsp_cmap:                                cmy
#     slc_phs.dsp_cmap:                                cmy
#     set_hddr:                                        0 bytes
#     set_tail:                                        0 bytes

# %%
for col in desc.columns:
    if col not in desc.columns[0]:
        if desc.loc[1,col] != '&':
            sub.attrs[col] =  str(desc.loc[0,col])+ ' ' +str(desc.loc[1,col])
        else:    
            sub.attrs[col] =  str(desc.loc[0,col])

# %%
sub.to_netcdf('../data/subsets/banner_lowman_05208_21019-019_21021-007_0006d.nc')

# %%
dssas
