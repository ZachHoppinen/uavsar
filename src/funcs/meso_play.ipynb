# %%
from MesoPy import Meso
import matplotlib.pyplot as plt
from tqdm import tqdm
import numpy as np
import pandas as pd

# %%
m = Meso(token='0191c61bf7914bd49b8bd7a98abb9469')
precip = m.precip(stid='kfnl', start='201504241800', end='201504271200', units='precip|in')

# %%
m.timeseries('201912201942', '202001312130', stid = 'BASI1', units = 'height|m')['UNITS']['snow_depth']
# Out:
# 'Millimeters'

# %%
from glob import glob
import rasterio as rio

# %%
# glob('/scratch/zacharykeskinen/jpl/*/tiffs/*')
fp = '/bsuscratch/zacharykeskinen/data/uavsar/images/Lowman, CO/lowman_05208_21012-004_21015-009_0021d_s01_L090_01_int_grd/lowman_05208_21012-004_21015-009_0021d_s01_L090HV_01.cor.grd.tiff'
with rio.open(fp) as src:
    bounds  = src.bounds

# %% [markdown]
# bbox: list, optional
#     Stations within a [lon/lat] box in the order [lonmin,latmin,lonmax,latmax] e.g. bbox="-120,40,-119,41"

# %%
stat
# Out:
# {'STATUS': 'ACTIVE',
#  'MNET_ID': '65',
#  'PERIOD_OF_RECORD': {'start': '2021-12-02T21:15:00Z',
#   'end': '2022-05-05T21:41:00Z'},
#  'ELEVATION': '2765',
#  'NAME': 'GW0891 Boise',
#  'STID': 'G0891',
#  'ELEV_DEM': '2755.9',
#  'LONGITUDE': '-116.20833',
#  'STATE': 'ID',
#  'RESTRICTED': False,
#  'LATITUDE': '43.59600',
#  'TIMEZONE': 'America/Boise',
#  'ID': '171054'}

# %%
for stat in m.metadata(start = '202002010000', end = '202002100000', bbox = bounds)['STATION']:
    name = stat['NAME']
    long = stat['LONGITUDE']
    lat = stat['LATITUDE']
    elev = stat['ELEVATION']
    stid = stat['STID']
    status = stat['STATUS']
    print(name)
    print(stid)
    print(lat)
    print(long)
    print(stid)
# Out:
# Stanley, Stanley Ranger Station
# KSNT
# 44.20861
# -114.93444
# KSNT
# BOISE
# BOII
# 43.60028
# -116.17667
# BOII
# ATLANTA SUMMIT
# ATAI1
# 43.75690
# -115.23907
# ATAI1
# BANNER SUMMIT
# BASI1
# 44.30342
# -115.23447
# BASI1
# BOGUS BASIN
# BOGI1
# 43.76377
# -116.09685
# BOGI1
# COZY COVE
# COZI1
# 44.28783
# -115.65527
# COZI1
# GRAHAM GUARD STA.
# GGSI1
# 43.95380
# -115.27387
# GGSI1
# JACKSON PEAK
# JKPI1
# 44.05092
# -115.44322
# JKPI1
# MORES CREEK SUMMIT
# MRKI1
# 43.93200
# -115.66588
# MRKI1
# TRINITY MTN.
# TRMI1
# 43.62903
# -115.43818
# TRMI1
# BANNER SUMMIT
# TMPE7
# 44.3
# -115.23
# TMPE7
# BEARSKIN CREEK
# BCFI1
# 44.385556
# -115.5505
# BCFI1
# CANYON CREEK
# TMPE8
# 44.23
# -115.25
# TMPE8
# CLASS III 7-C
# QEDA3
# 43.6
# -116.21
# QEDA3
# CRANE CREEK
# CRNI1
# 43.67
# -116.13
# CRNI1
# CURLEW CREEK
# CURI1
# 43.64
# FW2177 Boise
# F2177
# 43.61583
# -116.16467
# F2177
# FW3613 Boise
# F3613
# 43.57383
# -116.14367
# F3613
# W7OLA Placerville
# E4358
# 43.94367
# -115.94500
# E4358
# FW1696 Boise
# F1696
# 43.71950
# -116.24333
# F1696
# Idaho City
# A3921
# 43.82302
# -115.83856
# A3921
# Garden Valley
# A3922
# 44.10450
# -115.97239
# A3922
# PSU STAR Lab South Boise Village
# 1860P
# 43.58741
# -116.19650
# 1860P
# PSU STAR Lab Boise Harrison Blvd
# 1861P
# 43.63053
# -116.20746
# 1861P
# PSU STAR Lab Boise Azelea
# 1864P
# 43.67309
# -116.29046
# 1864P
# PSU STAR Lab Hidden Springs
# 1866P
# 43.72533
# -116.25415
# 1866P
# Boise Beekeeper
# 1868P
# 43.60015
# -116.25734
# 1868P
# RP's back porch
# 1869P
# 43.63614
# -116.21861
# 1869P
# PSU STAR LAB WINSTEAD PARK
# 1871P
# 43.62740
# -116.26270
# 1871P
# MesaVista
# 1872P
# 43.59602
# -116.20821
# 1872P
# PSU STAR Lab Northwest Boise City
# 1875P
# 43.67740
# -116.28817
# 1875P
# Idaho Conservation League - Boise
# 1878P
# 43.61911
# -116.19633
# 1878P
# Plateau Drive
# 1880P
# 43.61116
# -116.15678
# 1880P
# PSU STAR Lab boise Hillview
# 1881P
# 43.60585
# -116.17321
# 1881P
# BOISE STATE ATHLETICS
# 1883P
# 43.60246
# -116.19654
# 1883P
# Boise Eastman
# A4622
# 43.61638
# -116.20382
# A4622
# Boise Fire Station
# A4623
# 43.61889
# -116.21361
# A4623
# White Pine
# A4624
# 43.57760
# -116.17816
# A4624
# Psu Star Lab Boise Central Bench
# 3668P
# 43.60114
# -116.23659
# 3668P
# Flying Wye I-84 East Inbound
# ITDE4
# 43.59711
# -116.28891
# ITDE4
# Flying Wye I-84 East Outbound
# ITDE5
# 43.59317
# -116.27948
# ITDE5
# FW9179 Horseshoe Bend
# F9179
# 43.77150
# -116.10317
# F9179
# GW0891 Boise
# G0891
# 43.59600
# -116.20833
# G0891

# %%
def raster_box_extract(img, x_coord, y_coord, box_side = 5):
    meta = img.meta

    # Use the transform in the metadata and your coordinates
    try:
        rowcol = rio.transform.rowcol(meta['transform'], xs=x_coord, ys=y_coord)
        w = img.read(1, window=Window(rowcol[1], rowcol[0], box_side, box_side))
        return w
    except:
        pass
        # print('station outside bbox')

# %%
stat_ls = []
stid_ls = []
res = {}
for stat in m.metadata(start = start_flight, end = end_flight, bbox = bounds)['STATION']:
    long = float(stat['LONGITUDE'])
    lat = float(stat['LATITUDE'])
    with rio.open(fp) as src:
        w = raster_box_extract(src, long, lat)
    if len(w[~np.isnan(w)]) > 0:
        if stat['NAME'].lower().replace(' ','') not in stat_ls:
            obs = m.timeseries(start_flight, end_flight, stid = stat['STID'], vars = 'snow_depth')
            if obs:
                obs = obs['STATION'][0]['OBSERVATIONS']
                d = {}
                dt = pd.to_datetime(obs['date_time'])
                if 'snow_depth_set_1' in obs.keys():
                    d['datetime'] = dt
                    d['img_arr'] = w
                    d['snow_depth_set_1'] = obs['snow_depth_set_1']
                    for anc_col in ['air_temp_set_1','snow_water_equiv_set_1']:
                        if anc_col in obs.keys():
                            d[anc_col] = obs[anc_col]
                if d:
                    d['elev'] = stat['ELEVATION']
                    d['lat'] = stat['LATITUDE']
                    d['long'] = stat['LONGITUDE']
                    d['tz'] = stat['TIMEZONE']
                    res[stat['NAME']] = d
            
            stat_ls.append(stat['NAME'].lower().replace(' ',''))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /bsuhome/zacharykeskinen/uavsar/src/funcs/meso_play.ipynb Cell 10' in <cell line: 4>()
#       <a href='vscode-notebook-cell://ssh-remote%2Bborah/bsuhome/zacharykeskinen/uavsar/src/funcs/meso_play.ipynb#ch0000009vscode-remote?line=1'>2</a> stid_ls = []
#       <a href='vscode-notebook-cell://ssh-remote%2Bborah/bsuhome/zacharykeskinen/uavsar/src/funcs/meso_play.ipynb#ch0000009vscode-remote?line=2'>3</a> res = {}
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bborah/bsuhome/zacharykeskinen/uavsar/src/funcs/meso_play.ipynb#ch0000009vscode-remote?line=3'>4</a> for stat in m.metadata(start = start_flight, end = end_flight, bbox = bounds)['STATION']:
#       <a href='vscode-notebook-cell://ssh-remote%2Bborah/bsuhome/zacharykeskinen/uavsar/src/funcs/meso_play.ipynb#ch0000009vscode-remote?line=4'>5</a>     long = float(stat['LONGITUDE'])
#       <a href='vscode-notebook-cell://ssh-remote%2Bborah/bsuhome/zacharykeskinen/uavsar/src/funcs/meso_play.ipynb#ch0000009vscode-remote?line=5'>6</a>     lat = float(stat['LATITUDE'])
#
# NameError: name 'start_flight' is not defined

# %%
plt.imshow(res['Treeline']['img_arr'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /bsuhome/zacharykeskinen/uavsar/src/funcs/meso_play.ipynb Cell 11' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bborah/bsuhome/zacharykeskinen/uavsar/src/funcs/meso_play.ipynb#ch0000010vscode-remote?line=0'>1</a> plt.imshow(res['Treeline']['img_arr'])
#
# KeyError: 'Treeline'

# %%
stat_ls = []
stid_ls = []
for stat in m.metadata(start = start_flight, end = end_flight, bbox = bounds)['STATION']:
    long = float(stat['LONGITUDE'])
    lat = float(stat['LATITUDE'])
    with rio.open(fp) as src:
        w = raster_box_extract(src, long, lat)
    if len(w[~np.isnan(w)]) > 0:
        if stat['NAME'].lower().replace(' ','') not in stat_ls:

            stat = m.timeseries(start_flight, end_flight, stid = stat['STID'])
            res = {}
            d = {}
            obs = stat['OBSERVATIONS']

            dt = pd.to_datetime(obs['date_time'])
            if 'snow_depth_set_1' in obs.keys():
                d['datetime'] = dt
                d['snow_depth_set_1'] = obs['snow_depth_set_1']
                for anc_col in ['air_temp_set_1','snow_water_equiv_set_1']:
                    if anc_col in obs.keys():
                        d[anc_col] = obs[anc_col]
            if d:
                d['elev'] = stat['ELEVATION']
                d['lat'] = stat['LATITUDE']
                d['long'] = stat['LONGITUDE']
                d['tz'] = stat['TIMEZONE']
                res[stat['NAME']] = d
        stat_ls.append(stat['NAME'].lower().replace(' ',''))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /bsuhome/zacharykeskinen/uavsar/src/funcs/meso_play.ipynb Cell 12' in <cell line: 3>()
#       <a href='vscode-notebook-cell://ssh-remote%2Bborah/bsuhome/zacharykeskinen/uavsar/src/funcs/meso_play.ipynb#ch0000011vscode-remote?line=0'>1</a> stat_ls = []
#       <a href='vscode-notebook-cell://ssh-remote%2Bborah/bsuhome/zacharykeskinen/uavsar/src/funcs/meso_play.ipynb#ch0000011vscode-remote?line=1'>2</a> stid_ls = []
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bborah/bsuhome/zacharykeskinen/uavsar/src/funcs/meso_play.ipynb#ch0000011vscode-remote?line=2'>3</a> for stat in m.metadata(start = start_flight, end = end_flight, bbox = bounds)['STATION']:
#       <a href='vscode-notebook-cell://ssh-remote%2Bborah/bsuhome/zacharykeskinen/uavsar/src/funcs/meso_play.ipynb#ch0000011vscode-remote?line=3'>4</a>     long = float(stat['LONGITUDE'])
#       <a href='vscode-notebook-cell://ssh-remote%2Bborah/bsuhome/zacharykeskinen/uavsar/src/funcs/meso_play.ipynb#ch0000011vscode-remote?line=4'>5</a>     lat = float(stat['LATITUDE'])
#
# NameError: name 'start_flight' is not defined

# %%
a = m.timeseries(start = start_flight, end = end_flight, stid = stid_ls)

res = {}
for stat in a['STATION']:
    # print(stat['SENSOR_VARIABLES'])
    d = {}
    obs = stat['OBSERVATIONS']

    dt = pd.to_datetime(obs['date_time'])
    if 'snow_depth_set_1' in obs.keys():
        d['datetime'] = dt
        d['snow_depth_set_1'] = obs['snow_depth_set_1']
        for anc_col in ['air_temp_set_1','snow_water_equiv_set_1']:
            if anc_col in obs.keys():
                d[anc_col] = obs[anc_col]
    if d:
        d['elev'] = stat['ELEVATION']
        d['lat'] = stat['LATITUDE']
        d['long'] = stat['LONGITUDE']
        d['tz'] = stat['TIMEZONE']
        res[stat['NAME']] = d
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /bsuhome/zacharykeskinen/uavsar/src/funcs/meso_play.ipynb Cell 13' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bborah/bsuhome/zacharykeskinen/uavsar/src/funcs/meso_play.ipynb#ch0000012vscode-remote?line=0'>1</a> a = m.timeseries(start = start_flight, end = end_flight, stid = stid_ls)
#       <a href='vscode-notebook-cell://ssh-remote%2Bborah/bsuhome/zacharykeskinen/uavsar/src/funcs/meso_play.ipynb#ch0000012vscode-remote?line=2'>3</a> res = {}
#       <a href='vscode-notebook-cell://ssh-remote%2Bborah/bsuhome/zacharykeskinen/uavsar/src/funcs/meso_play.ipynb#ch0000012vscode-remote?line=3'>4</a> for stat in a['STATION']:
#       <a href='vscode-notebook-cell://ssh-remote%2Bborah/bsuhome/zacharykeskinen/uavsar/src/funcs/meso_play.ipynb#ch0000012vscode-remote?line=4'>5</a>     # print(stat['SENSOR_VARIABLES'])
#
# NameError: name 'start_flight' is not defined

# %%
for col in ann_df.columns:
    if 'acq' in col:
        print(col)

# %%
ann_df = pd.read_csv('/home/zacharykeskinen/uavsar/data/slc_stack/lowman_23205_20002-007_20007-003_0013d_s01_L090_01_int_grd/lowman_23205_20002-007_20007-003_0013d_s01_L090_01_int_grd.csv')
start = pd.to_datetime(ann_df['stop time of acquisition for pass 1'][0])
end = pd.to_datetime(ann_df['start time of acquisition for pass 2'][0])

# %%
def mesopy_date_parse(pd_date_str):
    return pd_date_str.strftime('%Y') + pd_date_str.strftime('%m') + pd_date_str.strftime('%d') + pd_date_str.strftime('%H') + pd_date_str.strftime('%M')

# %%
mesopy_date_parse(pd.to_datetime('2020-10-04T20:30'))

# %%
import datetime
isinstance((pd.to_datetime('2020-10-01')), datetime.datetime)

# %%
start.month

# %%
start_flight = '202001010000'
end_flight = '202001070000'
a = m.timeseries(start_flight, end_flight, stid = 'BASI1' )
dt = a['STATION'][0]['OBSERVATIONS']['date_time']
sd = a['STATION'][0]['OBSERVATIONS']['snow_depth_set_1']
swe = a['STATION'][0]['OBSERVATIONS']['snow_water_equiv_set_1']
temp = a['STATION'][0]['OBSERVATIONS']['air_temp_set_1']
a['STATION'][0]['OBSERVATIONS'].keys()

# %%
from rasterio.windows import Window    
with rio.open(fp) as src:
    meta = src.meta

    # My target coordinates
    x_coord = -115.23447
    y_coord = 44.30342

    # Use the transform in the metadata and your coordinates
    rowcol = rio.transform.rowcol(meta['transform'], xs=x_coord, ys=y_coord)

    w = src.read(1, window=Window(rowcol[1], rowcol[0], 5, 5))
    # Do something with your data here.
    print(w)

# %%
df =pd.read_csv('/home/zacharykeskinen/uavsar/results/test_wx.csv')

# %%
plt.plot(df.set_index('Unnamed: 0')['BANNER SUMMIT']['snow_depth_set_1'])

# %%
import pickle
with open('/home/zacharykeskinen/uavsar/results/test_wx.pkl', 'rb') as f:
    res  = pickle.load(f)

# %%
plt.scatter(res['Lower Weather']['snow_depth_set_1'])

# %%
for site,obs in res.items():
    print(site)
    #print(obs)
    plt.scatter(obs['datetime'], obs['snow_depth_set_1'])
    plt.show()
